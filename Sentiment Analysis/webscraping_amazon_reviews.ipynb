# %% [markdown]
# ### 1. Importing Modules

# %%
import os
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from sklearn.feature_extraction.text import CountVectorizer
from gensim.models import LdaModel
from gensim import corpora
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import plotly.express as px
from dash import Dash, html, dcc
import plotly.graph_objs as go
from dash.dependencies import Input, Output

# %% [markdown]
# ### 2a. Webscraping (for Safari)

# %%
# Initialize SafariDriver
driver = webdriver.Safari()

# Load the CSV with Amazon product links and product info
file_path = '/Users/valerielim/Documents/DSA3101/E-commerce-Performance-Analysis-and-Optimization/LLM/data/amazon.csv'
amazon_data = pd.read_csv(file_path)

# Assuming the columns are named 'product_link', 'product_id', 'product_name', 'product_category'
urls = amazon_data['product_link'] # Process the first 3 links
product_ids = amazon_data['product_id']
product_names = amazon_data['product_name']
product_categories = amazon_data['category']

# Create a DataFrame to store all the reviews from all products
all_reviews = []

# Loop through each URL and its corresponding product data in the CSV file
for index, url in enumerate(urls):
    print(f"Scraping URL: {url}")
    driver.get(url)
    
    # Wait for the page to load fully (adjust the delay as needed)
    time.sleep(10)  # Wait for 10 seconds to ensure the page fully loads
    
    # Scroll to load the reviews section
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Find the reviews, ratings, and dates
    reviews = driver.find_elements(By.CLASS_NAME, 'review-text-content')
    ratings = driver.find_elements(By.CSS_SELECTOR, '.a-icon-alt')  # More specific selector
    dates = driver.find_elements(By.CLASS_NAME, 'review-date')
    
    # Print counts for debugging
    review_count = len(reviews)
    rating_count = len(ratings)
    date_count = len(dates)
    print(f"Found {review_count} reviews, {rating_count} ratings, and {date_count} dates.")
    
    # Summary for each URL
    summary = f"Found {review_count} reviews, {rating_count} ratings, and {date_count} dates."
    
    # Combine the reviews, ratings, and dates into single strings
    reviews_combined = " | ".join([review.text.strip() if review.text.strip() else "N/A" for review in reviews])
    ratings_combined = " | ".join([rating.get_attribute("innerHTML").strip() if rating.get_attribute("innerHTML").strip() else "N/A" for rating in ratings])
    dates_combined = " | ".join([date.text.strip() if date.text.strip() else "N/A" for date in dates])

    # Append the data for this URL along with product details
    all_reviews.append({
        'url': url,
        'product_id': product_ids[index],          # Add product_id
        'product_name': product_names[index],      # Add product_name
        'product_category': product_categories[index],  # Add product_category
        'summary': summary,
        'reviews': reviews_combined,
        'ratings': ratings_combined,
        'dates': dates_combined
    })

# Close the WebDriver
driver.quit()
# Out:
# Scraping URL: https://www.amazon.in/Wayona-Braided-WN3LG1-Syncing-Charging/dp/B07JW9H4J1/ref=sr_1_1?qid=1672909124&s=electronics&sr=1-1
# Found 9 reviews, 41 ratings, and 9 dates.
# Scraping URL: https://www.amazon.in/Ambrane-Unbreakable-Charging-Braided-Cable/dp/B098NS6PVG/ref=sr_1_2?qid=1672909124&s=electronics&sr=1-2
# Found 8 reviews, 39 ratings, and 8 dates.
# Scraping URL: https://www.amazon.in/Sounce-iPhone-Charging-Compatible-Devices/dp/B096MSW6CT/ref=sr_1_3?qid=1672909124&s=electronics&sr=1-3
# Found 8 reviews, 50 ratings, and 8 dates.
# Scraping URL: https://www.amazon.in/Deuce-300-Resistant-Tangle-Free-Transmission/dp/B08HDJ86NZ/ref=sr_1_4?qid=1672909124&s=electronics&sr=1-4
# Found 8 reviews, 41 ratings, and 8 dates.
# Scraping URL: https://www.amazon.in/
output_dir = '/Users/valerielim/Documents/DSA3101/E-commerce-Performance-Analysis-and-Optimization/SubgroupB/webscraping/'
os.makedirs(output_dir, exist_ok=True)

# Save the reviews from the links into a CSV file
output_file = os.path.join(output_dir, 'all_amazon_reviews_with_summary_safari.csv')
df.to_csv(output_file, index=False)

print(f"Scraped reviews from {len(urls)} URLs.")
# Out:
# Scraped reviews from 1465 URLs.

# %% [markdown]
# ### 2b. Webscraping (for Chrome)

# %%
# Path to your ChromeDriver executable
chrome_driver_path = '/Users/valerielim/Downloads/chromedriver-mac-arm64/chromedriver'  # Adjust the path to your actual chromedriver file

# Initialize ChromeDriver with binary and service path
chrome_options = Options()
service = Service(executable_path=chrome_driver_path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# Load the CSV with Amazon product links and product info
file_path = '/Users/valerielim/Documents/DSA3101/E-commerce-Performance-Analysis-and-Optimization/LLM/data/amazon.csv'
amazon_data = pd.read_csv(file_path)

# Assuming the columns are named 'product_link', 'product_id', 'product_name', 'product_category'
urls = amazon_data['product_link'][:3]  # Process the first 3 links
product_ids = amazon_data['product_id'][:3]
product_names = amazon_data['product_name'][:3]
product_categories = amazon_data['category'][:3]

# Create a DataFrame to store all the reviews from all products
all_reviews = []

# Loop through each URL and its corresponding product data in the CSV file
for index, url in enumerate(urls):
    print(f"Scraping URL: {url}")
    driver.get(url)
    
    # Wait for the page to load fully (adjust the delay as needed)
    time.sleep(10)  # Wait for 10 seconds to ensure the page fully loads
    
    # Scroll to load the reviews section
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Find the reviews, ratings, and dates
    reviews = driver.find_elements(By.CLASS_NAME, 'review-text-content')
    ratings = driver.find_elements(By.CSS_SELECTOR, '.a-icon-alt')  # More specific selector
    dates = driver.find_elements(By.CLASS_NAME, 'review-date')
    
    # Print counts for debugging
    review_count = len(reviews)
    rating_count = len(ratings)
    date_count = len(dates)
    print(f"Found {review_count} reviews, {rating_count} ratings, and {date_count} dates.")
    
    # Summary for each URL
    summary = f"Found {review_count} reviews, {rating_count} ratings, and {date_count} dates."
    
    # Combine the reviews, ratings, and dates into single strings
    reviews_combined = " | ".join([review.text.strip() if review.text.strip() else "N/A" for review in reviews])
    ratings_combined = " | ".join([rating.get_attribute("innerHTML").strip() if rating.get_attribute("innerHTML").strip() else "N/A" for rating in ratings])
    dates_combined = " | ".join([date.text.strip() if date.text.strip() else "N/A" for date in dates])

    # Append the data for this URL along with product details
    all_reviews.append({
        'url': url,
        'product_id': product_ids[index],          # Add product_id
        'product_name': product_names[index],      # Add product_name
        'product_category': product_categories[index],  # Add product_category
        'summary': summary,
        'reviews': reviews_combined,
        'ratings': ratings_combined,
        'dates': dates_combined
    })

# Close the WebDriver
driver.quit()

# %%
# Convert the list of dictionaries into a DataFrame
df = pd.DataFrame(all_reviews)

# Define the output directory and ensure it exists
output_dir = '/Users/valerielim/Documents/DSA3101/E-commerce-Performance-Analysis-and-Optimization/SubgroupB/webscraping/'
os.makedirs(output_dir, exist_ok=True)

# Save the reviews from the links into a CSV file
output_file = os.path.join(output_dir, 'all_amazon_reviews_with_summary_chrome.csv')
df.to_csv(output_file, index=False)

print(f"Scraped reviews from {len(urls)} URLs.")

# %% [markdown]
# ### 3. To reset if needed

# %%
driver.quit()

# %% [markdown]
# ### 4. Sentiment Analysis

# %% [markdown]
# Between the two options:
#
# 1. Sentiment analysis first, then group by categories to find the mean: This approach allows you to capture the sentiment for each individual review or product before aggregating the results. It gives more granular insights, and then grouping by category will provide a mean sentiment score that reflects the overall feeling of buyers within that category. This method retains more detailed information and might provide a better understanding of how individual products within a category contribute to the overall sentiment.
# 2. Group by categories first, find the mean, then do sentiment analysis: If you aggregate the data before performing sentiment analysis, you might lose specific details related to each review. Sentiment analysis on a pre-aggregated summary of reviews might not be as precise because it will analyze the combined text from multiple reviews, which could mix positive and negative feedback, making the sentiment score less accurate.
#
# Chosen method: Option 1 (sentiment analysis first, then group by categories) is typically better because it allows for more precise sentiment analysis on individual reviews before aggregating. This way, you can capture sentiment variations and avoid diluting insights when multiple reviews are combined.

# %% [markdown]
# #### 4a. Perform Sentiment Analysis

# %%
# Load the CSV file
file_path = '/Users/valerielim/Documents/DSA3101-project/E-commerce-Performance-Analysis-and-Optimization/SubgroupB/webscraping/all_amazon_reviews_with_summary_safari.csv'
data = pd.read_csv(file_path)

# Initialize VADER sentiment analyzer
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

# Perform sentiment analysis on the 'reviews' column
data['sentiment_scores'] = data['reviews'].apply(lambda review: sid.polarity_scores(str(review)))

# Extract compound sentiment scores and sentiment labels
data['compound'] = data['sentiment_scores'].apply(lambda score_dict: score_dict['compound'])
data['sentiment'] = data['compound'].apply(lambda c: 'positive' if c >= 0.05 else ('negative' if c <= -0.05 else 'neutral'))

# Save the sentiment results back to a CSV file
output_file = '/Users/valerielim/Documents/DSA3101-project/E-commerce-Performance-Analysis-and-Optimization/SubgroupB/webscraping/sentiment_analysis_results.csv'
data.to_csv(output_file, index=False)
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>

# %% [markdown]
# #### 4b. Finding the average compound sentiment scores and sentiment labels by category

# %%
# Load the sentiment analysis results CSV
file_path = '/Users/valerielim/Documents/DSA3101-project/E-commerce-Performance-Analysis-and-Optimization/SubgroupB/webscraping/sentiment_analysis_results.csv'
data = pd.read_csv(file_path)

# Function to count the number of concatenated items (reviews/ratings)
def count_concatenated_items(column):
    return column.apply(lambda x: len(x.split(" | ")) if pd.notnull(x) and x.strip() != "" else 0)

# Group by product category
grouped_data = data.groupby('product_category')

# Calculate the mean of compound scores for each group
mean_compound = grouped_data['compound'].mean()

# Find the most common sentiment label for each group
most_common_sentiment = grouped_data['sentiment'].agg(lambda x: x.value_counts().index[0])

# Count the number of products in each category
product_count = grouped_data['product_id'].nunique()

# Accurately count the total number of reviews and ratings
total_reviews = grouped_data['reviews'].apply(lambda x: count_concatenated_items(x).sum())
total_ratings = grouped_data['ratings'].apply(lambda x: count_concatenated_items(x).sum())

# Combine all the metrics into a single DataFrame
summary = pd.DataFrame({
    'mean_compound': mean_compound,
    'most_common_sentiment': most_common_sentiment,
    'number_of_products': product_count,
    'total_reviews': total_reviews,
    'total_ratings': total_ratings
})

# Save the summary to a CSV file
output_file = '/Users/valerielim/Documents/DSA3101-project/E-commerce-Performance-Analysis-and-Optimization/SubgroupB/webscraping/sentiment_summary_by_category_with_counts.csv'
summary.to_csv(output_file, index=True)

print("\nSentiment Scores and Labels by Product Category:\n")
for category, row in summary.iterrows():
    print(f"Category: {category}")
    print(f"  Mean Compound Score: {row['mean_compound']}")
    print(f"  Most Common Sentiment: {row['most_common_sentiment']}")
    print(f"  Number of Products: {row['number_of_products']}")
    print(f"  Total Reviews: {row['total_reviews']}")
    print(f"  Total Ratings: {row['total_ratings']}")
    print("\n")
# Out:
# Sentiment Scores and Labels by Product Category:
#
# Category: Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers
#   Mean Compound Score: 0.999
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 42
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters
#   Mean Compound Score: 0.96975
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 89
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets
#   Mean Compound Score: 0.9923
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 33
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones
#   Mean Compound Score: 0.9863999999999999
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 21
#   Total Ratings: 79
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers
#   Mean Compound Score: 0.9965999999999999
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 18
#   Total Ratings: 74
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|Webcams&VoIPEquipment|Webcams
#   Mean Compound Score: 0.9936
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 26
#   Total Ratings: 86
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors
#   Mean Compound Score: 0.9966666666666667
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 24
#   Total Ratings: 95
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|DVICables
#   Mean Compound Score: 0.9854
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 45
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|EthernetCables
#   Mean Compound Score: 0.98665
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 76
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|SATACables
#   Mean Compound Score: 0.9746
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 41
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables
#   Mean Compound Score: 0.9205270386266095
#   Most Common Sentiment: positive
#   Number of Products: 161
#   Total Reviews: 2068
#   Total Ratings: 8796
#
#
# Category: Computers&Accessories|Accessories&Peripherals|HardDiskBags
#   Mean Compound Score: 0.9883000000000001
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 29
#   Total Ratings: 99
#
#
# Category: Computers&Accessories|Accessories&Peripherals|HardDriveAccessories|Caddies
#   Mean Compound Score: 0.996
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 37
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|GraphicTablets
#   Mean Compound Score: 0.7492272727272727
#   Most Common Sentiment: positive
#   Number of Products: 11
#   Total Reviews: 84
#   Total Ratings: 382
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|DustCovers
#   Mean Compound Score: 0.9562
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 81
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|MousePads
#   Mean Compound Score: 0.9949875
#   Most Common Sentiment: positive
#   Number of Products: 8
#   Total Reviews: 64
#   Total Ratings: 290
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MouseSets
#   Mean Compound Score: 0.7977299999999999
#   Most Common Sentiment: positive
#   Number of Products: 10
#   Total Reviews: 104
#   Total Ratings: 402
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboards
#   Mean Compound Score: 0.9633800000000001
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 51
#   Total Ratings: 168
#
#
# Category: Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Mice
#   Mean Compound Score: 0.9751208333333333
#   Most Common Sentiment: positive
#   Number of Products: 24
#   Total Reviews: 259
#   Total Ratings: 951
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories
#   Mean Compound Score: 0.9887
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 36
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories|Bags&Sleeves|LaptopSleeves&Slipcases
#   Mean Compound Score: 0.9974500000000001
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 48
#   Total Ratings: 257
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories|CameraPrivacyCovers
#   Mean Compound Score: 0.9987
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 24
#   Total Ratings: 129
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories|CoolingPads
#   Mean Compound Score: 0.9984
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 15
#   Total Ratings: 69
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories|Lapdesks
#   Mean Compound Score: 0.8013214285714286
#   Most Common Sentiment: positive
#   Number of Products: 14
#   Total Reviews: 109
#   Total Ratings: 514
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories|LaptopChargers&PowerSupplies
#   Mean Compound Score: 0.44820000000000004
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 37
#   Total Ratings: 149
#
#
# Category: Computers&Accessories|Accessories&Peripherals|LaptopAccessories|NotebookComputerStands
#   Mean Compound Score: 0.9992000000000001
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 31
#   Total Ratings: 128
#
#
# Category: Computers&Accessories|Accessories&Peripherals|PCGamingPeripherals|Gamepads
#   Mean Compound Score: 0.9978333333333333
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 126
#
#
# Category: Computers&Accessories|Accessories&Peripherals|PCGamingPeripherals|GamingKeyboards
#   Mean Compound Score: 0.9996
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 19
#   Total Ratings: 105
#
#
# Category: Computers&Accessories|Accessories&Peripherals|PCGamingPeripherals|GamingMice
#   Mean Compound Score: 0.9974500000000001
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 55
#   Total Ratings: 232
#
#
# Category: Computers&Accessories|Accessories&Peripherals|PCGamingPeripherals|Headsets
#   Mean Compound Score: 0.9993333333333334
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 20
#   Total Ratings: 102
#
#
# Category: Computers&Accessories|Accessories&Peripherals|TabletAccessories|Bags,Cases&Sleeves|Cases
#   Mean Compound Score: 0.9899
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 17
#   Total Ratings: 96
#
#
# Category: Computers&Accessories|Accessories&Peripherals|TabletAccessories|ScreenProtectors
#   Mean Compound Score: 0.9934200000000001
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 45
#   Total Ratings: 249
#
#
# Category: Computers&Accessories|Accessories&Peripherals|TabletAccessories|Stands
#   Mean Compound Score: 0.9963
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 34
#
#
# Category: Computers&Accessories|Accessories&Peripherals|USBGadgets|Lamps
#   Mean Compound Score: 0.78756
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 37
#   Total Ratings: 155
#
#
# Category: Computers&Accessories|Accessories&Peripherals|USBHubs
#   Mean Compound Score: 0.9728199999999999
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 40
#   Total Ratings: 199
#
#
# Category: Computers&Accessories|Accessories&Peripherals|UninterruptedPowerSupplies
#   Mean Compound Score: 0.9991
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 32
#
#
# Category: Computers&Accessories|Components|InternalHardDrives
#   Mean Compound Score: 0.998
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 38
#
#
# Category: Computers&Accessories|Components|InternalSolidStateDrives
#   Mean Compound Score: 0.9989333333333333
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 39
#   Total Ratings: 132
#
#
# Category: Computers&Accessories|Components|Memory
#   Mean Compound Score: 0.995
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 47
#
#
# Category: Computers&Accessories|ExternalDevices&DataStorage|ExternalHardDisks
#   Mean Compound Score: 0.99795
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 70
#   Total Ratings: 260
#
#
# Category: Computers&Accessories|ExternalDevices&DataStorage|ExternalMemoryCardReaders
#   Mean Compound Score: 0.9982
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 39
#
#
# Category: Computers&Accessories|ExternalDevices&DataStorage|ExternalSolidStateDrives
#   Mean Compound Score: 0.995
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 47
#
#
# Category: Computers&Accessories|ExternalDevices&DataStorage|PenDrives
#   Mean Compound Score: 0.99526
#   Most Common Sentiment: positive
#   Number of Products: 10
#   Total Reviews: 130
#   Total Ratings: 443
#
#
# Category: Computers&Accessories|Laptops|TraditionalLaptops
#   Mean Compound Score: 0.9616
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 31
#
#
# Category: Computers&Accessories|Monitors
#   Mean Compound Score: 0.9993
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 69
#
#
# Category: Computers&Accessories|NetworkingDevices
#   Mean Compound Score: 0.9962
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 37
#
#
# Category: Computers&Accessories|NetworkingDevices|DataCards&Dongles
#   Mean Compound Score: 0.8824
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 41
#
#
# Category: Computers&Accessories|NetworkingDevices|NetworkAdapters|BluetoothAdapters
#   Mean Compound Score: 0.9985
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 12
#   Total Ratings: 41
#
#
# Category: Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters
#   Mean Compound Score: 0.9882
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 53
#
#
# Category: Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters
#   Mean Compound Score: 0.9460444444444445
#   Most Common Sentiment: positive
#   Number of Products: 14
#   Total Reviews: 200
#   Total Ratings: 752
#
#
# Category: Computers&Accessories|NetworkingDevices|Repeaters&Extenders
#   Mean Compound Score: 0.9870666666666666
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 39
#   Total Ratings: 147
#
#
# Category: Computers&Accessories|NetworkingDevices|Routers
#   Mean Compound Score: 0.9939444444444443
#   Most Common Sentiment: positive
#   Number of Products: 9
#   Total Reviews: 77
#   Total Ratings: 348
#
#
# Category: Computers&Accessories|Printers,Inks&Accessories|Inks,Toners&Cartridges|InkjetInkCartridges
#   Mean Compound Score: 0.94235
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 36
#   Total Ratings: 163
#
#
# Category: Computers&Accessories|Printers,Inks&Accessories|Inks,Toners&Cartridges|InkjetInkRefills&Kits
#   Mean Compound Score: 0.9867
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 35
#
#
# Category: Computers&Accessories|Printers,Inks&Accessories|Inks,Toners&Cartridges|TonerCartridges
#   Mean Compound Score: 0.9923
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 38
#
#
# Category: Computers&Accessories|Printers,Inks&Accessories|Printers
#   Mean Compound Score: 0.3921333333333334
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 105
#
#
# Category: Computers&Accessories|Printers,Inks&Accessories|Printers|InkjetPrinters
#   Mean Compound Score: 0.9815499999999999
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 10
#   Total Ratings: 75
#
#
# Category: Computers&Accessories|Tablets
#   Mean Compound Score: 0.9996
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 4
#   Total Ratings: 44
#
#
# Category: Electronics|Accessories|MemoryCards|MicroSD
#   Mean Compound Score: 0.9306384615384615
#   Most Common Sentiment: positive
#   Number of Products: 10
#   Total Reviews: 169
#   Total Ratings: 566
#
#
# Category: Electronics|Accessories|MemoryCards|SecureDigitalCards
#   Mean Compound Score: 0.9993
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 41
#
#
# Category: Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers
#   Mean Compound Score: -0.8315
#   Most Common Sentiment: negative
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 33
#
#
# Category: Electronics|Cameras&Photography|Accessories|Cleaners|CleaningKits
#   Mean Compound Score: 0.0
#   Most Common Sentiment: neutral
#   Number of Products: 1
#   Total Reviews: 0
#   Total Ratings: 0
#
#
# Category: Electronics|Cameras&Photography|Accessories|Film
#   Mean Compound Score: 0.8898
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 35
#
#
# Category: Electronics|Cameras&Photography|Accessories|PhotoStudio&Lighting|PhotoBackgroundAccessories|BackgroundSupports
#   Mean Compound Score: 0.9937
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 35
#
#
# Category: Electronics|Cameras&Photography|Accessories|Tripods&Monopods|CompleteTripodUnits
#   Mean Compound Score: 0.9998
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 7
#   Total Ratings: 39
#
#
# Category: Electronics|Cameras&Photography|Accessories|Tripods&Monopods|Tabletop&TravelTripods
#   Mean Compound Score: 0.9952000000000001
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 17
#   Total Ratings: 81
#
#
# Category: Electronics|Cameras&Photography|Accessories|Tripods&Monopods|TripodLegs
#   Mean Compound Score: 0.98675
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 75
#
#
# Category: Electronics|Cameras&Photography|Flashes|Macro&RinglightFlashes
#   Mean Compound Score: 0.9981
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 43
#
#
# Category: Electronics|Cameras&Photography|SecurityCameras|DomeCameras
#   Mean Compound Score: 0.99088
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 41
#   Total Ratings: 185
#
#
# Category: Electronics|Cameras&Photography|VideoCameras
#   Mean Compound Score: 0.999
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 27
#
#
# Category: Electronics|GeneralPurposeBatteries&BatteryChargers
#   Mean Compound Score: 0.9768749999999999
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 38
#   Total Ratings: 158
#
#
# Category: Electronics|GeneralPurposeBatteries&BatteryChargers|DisposableBatteries
#   Mean Compound Score: 0.9307285714285715
#   Most Common Sentiment: positive
#   Number of Products: 7
#   Total Reviews: 61
#   Total Ratings: 269
#
#
# Category: Electronics|GeneralPurposeBatteries&BatteryChargers|RechargeableBatteries
#   Mean Compound Score: 0.7552666666666666
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 34
#   Total Ratings: 128
#
#
# Category: Electronics|Headphones,Earbuds&Accessories|Adapters
#   Mean Compound Score: 0.9977
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 14
#   Total Ratings: 74
#
#
# Category: Electronics|Headphones,Earbuds&Accessories|Cases
#   Mean Compound Score: 0.9937
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 31
#
#
# Category: Electronics|Headphones,Earbuds&Accessories|Earpads
#   Mean Compound Score: 0.7264
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 35
#
#
# Category: Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear
#   Mean Compound Score: 0.9761961538461539
#   Most Common Sentiment: positive
#   Number of Products: 51
#   Total Reviews: 426
#   Total Ratings: 1901
#
#
# Category: Electronics|Headphones,Earbuds&Accessories|Headphones|On-Ear
#   Mean Compound Score: 0.99805
#   Most Common Sentiment: positive
#   Number of Products: 7
#   Total Reviews: 57
#   Total Ratings: 302
#
#
# Category: Electronics|Headphones,Earbuds&Accessories|Headphones|Over-Ear
#   Mean Compound Score: 0.99895
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 9
#   Total Ratings: 67
#
#
# Category: Electronics|HomeAudio|Accessories|Adapters
#   Mean Compound Score: 0.9944
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 45
#
#
# Category: Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts
#   Mean Compound Score: 0.9986
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 37
#
#
# Category: Electronics|HomeAudio|MediaStreamingDevices|StreamingClients
#   Mean Compound Score: 0.9742
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 21
#
#
# Category: Electronics|HomeAudio|Speakers|BluetoothSpeakers
#   Mean Compound Score: 0.69915
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 56
#   Total Ratings: 222
#
#
# Category: Electronics|HomeAudio|Speakers|MultimediaSpeakerSystems
#   Mean Compound Score: 0.996
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 35
#
#
# Category: Electronics|HomeAudio|Speakers|OutdoorSpeakers
#   Mean Compound Score: 0.98315
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 22
#   Total Ratings: 133
#
#
# Category: Electronics|HomeAudio|Speakers|SoundbarSpeakers
#   Mean Compound Score: 0.998
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 10
#   Total Ratings: 33
#
#
# Category: Electronics|HomeAudio|Speakers|TowerSpeakers
#   Mean Compound Score: 0.9981
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 40
#
#
# Category: Electronics|HomeTheater,TV&Video|AVReceivers&Amplifiers
#   Mean Compound Score: 0.9959
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 37
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|3DGlasses
#   Mean Compound Score: 0.9997
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 4
#   Total Ratings: 33
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables
#   Mean Compound Score: 0.9486249999999999
#   Most Common Sentiment: positive
#   Number of Products: 21
#   Total Reviews: 245
#   Total Ratings: 924
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables
#   Mean Compound Score: 0.9968666666666667
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 39
#   Total Ratings: 127
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables
#   Mean Compound Score: 0.994
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 26
#   Total Ratings: 87
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|Cables|SpeakerCables
#   Mean Compound Score: 0.9975
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 33
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|RemoteControls
#   Mean Compound Score: 0.8065244897959184
#   Most Common Sentiment: positive
#   Number of Products: 49
#   Total Reviews: 381
#   Total Ratings: 1752
#
#
# Category: Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts
#   Mean Compound Score: 0.9830833333333334
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 48
#   Total Ratings: 231
#
#
# Category: Electronics|HomeTheater,TV&Video|Projectors
#   Mean Compound Score: 0.9991
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 22
#   Total Ratings: 138
#
#
# Category: Electronics|HomeTheater,TV&Video|SatelliteEquipment|SatelliteReceivers
#   Mean Compound Score: 0.9573333333333333
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 120
#
#
# Category: Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions
#   Mean Compound Score: 0.8717904761904762
#   Most Common Sentiment: positive
#   Number of Products: 60
#   Total Reviews: 428
#   Total Ratings: 2002
#
#
# Category: Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions
#   Mean Compound Score: 0.9891166666666668
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 44
#   Total Ratings: 180
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|AutomobileAccessories|Cradles
#   Mean Compound Score: 0.9965666666666667
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 28
#   Total Ratings: 110
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Cables&Adapters|OTGAdapters
#   Mean Compound Score: 0.007349999999999968
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 77
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Cases&Covers|BasicCases
#   Mean Compound Score: 0.973075
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 38
#   Total Ratings: 169
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Chargers|AutomobileChargers
#   Mean Compound Score: 0.99362
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 34
#   Total Ratings: 176
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Chargers|PowerBanks
#   Mean Compound Score: 0.9974666666666666
#   Most Common Sentiment: positive
#   Number of Products: 11
#   Total Reviews: 85
#   Total Ratings: 483
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Chargers|WallChargers
#   Mean Compound Score: 0.77296875
#   Most Common Sentiment: positive
#   Number of Products: 15
#   Total Reviews: 104
#   Total Ratings: 478
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Décor
#   Mean Compound Score: 0.99254
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 40
#   Total Ratings: 177
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms
#   Mean Compound Score: 0.9928
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 34
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Maintenance,Upkeep&Repairs|ScreenProtectors
#   Mean Compound Score: 0.7377428571428571
#   Most Common Sentiment: positive
#   Number of Products: 7
#   Total Reviews: 65
#   Total Ratings: 274
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Mounts|Bedstand&DeskMounts
#   Mean Compound Score: 0.98355
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 76
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Mounts|HandlebarMounts
#   Mean Compound Score: 0.9995
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 40
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Mounts|Shower&WallMounts
#   Mean Compound Score: 0.998
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 42
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Photo&VideoAccessories|Flashes&SelfieLights|SelfieLights
#   Mean Compound Score: 0.9749
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 39
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Photo&VideoAccessories|SelfieSticks
#   Mean Compound Score: 0.9986600000000001
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 40
#   Total Ratings: 198
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Photo&VideoAccessories|Tripods
#   Mean Compound Score: 0.999
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 57
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|Stands
#   Mean Compound Score: 0.99321
#   Most Common Sentiment: positive
#   Number of Products: 10
#   Total Reviews: 86
#   Total Ratings: 379
#
#
# Category: Electronics|Mobiles&Accessories|MobileAccessories|StylusPens
#   Mean Compound Score: 0.8697874999999999
#   Most Common Sentiment: positive
#   Number of Products: 5
#   Total Reviews: 88
#   Total Ratings: 348
#
#
# Category: Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|BasicMobiles
#   Mean Compound Score: 0.9907333333333335
#   Most Common Sentiment: positive
#   Number of Products: 9
#   Total Reviews: 87
#   Total Ratings: 389
#
#
# Category: Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones
#   Mean Compound Score: 0.9791338235294118
#   Most Common Sentiment: positive
#   Number of Products: 68
#   Total Reviews: 510
#   Total Ratings: 2744
#
#
# Category: Electronics|PowerAccessories|SurgeProtectors
#   Mean Compound Score: 0.999
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 9
#   Total Ratings: 37
#
#
# Category: Electronics|WearableTechnology|SmartWatches
#   Mean Compound Score: 0.8330026315789474
#   Most Common Sentiment: positive
#   Number of Products: 62
#   Total Reviews: 536
#   Total Ratings: 2642
#
#
# Category: Health&PersonalCare|HomeMedicalSupplies&Equipment|HealthMonitors|WeighingScales|DigitalBathroomScales
#   Mean Compound Score: 0.9998
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 39
#
#
# Category: Home&Kitchen|CraftMaterials|DrawingMaterials|DrawingMedia|Pencils|WoodenPencils
#   Mean Compound Score: 0.9395
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 28
#
#
# Category: Home&Kitchen|CraftMaterials|DrawingMaterials|DrawingMedia|Pens
#   Mean Compound Score: 0.9973
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 33
#
#
# Category: Home&Kitchen|CraftMaterials|PaintingMaterials
#   Mean Compound Score: 0.9983
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 37
#
#
# Category: Home&Kitchen|CraftMaterials|PaintingMaterials|Paints
#   Mean Compound Score: 0.9926333333333334
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 27
#   Total Ratings: 127
#
#
# Category: Home&Kitchen|CraftMaterials|Scrapbooking|Tape
#   Mean Compound Score: 0.9972
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 37
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|AirConditioners|Split-SystemAirConditioners
#   Mean Compound Score: 0.9983
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 6
#   Total Ratings: 28
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|AirPurifiers|HEPAAirPurifiers
#   Mean Compound Score: 0.9993500000000001
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 26
#   Total Ratings: 148
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|Fans|CeilingFans
#   Mean Compound Score: 0.9827909090909092
#   Most Common Sentiment: positive
#   Number of Products: 11
#   Total Reviews: 88
#   Total Ratings: 462
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|Fans|ExhaustFans
#   Mean Compound Score: 0.9792666666666667
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 131
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|Fans|PedestalFans
#   Mean Compound Score: 0.9997
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 42
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|Fans|TableFans
#   Mean Compound Score: 0.997
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 75
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|Humidifiers
#   Mean Compound Score: 0.6546666666666666
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 16
#   Total Ratings: 83
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|Parts&Accessories|FanParts&Accessories
#   Mean Compound Score: 0.9821
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 39
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|RoomHeaters
#   Mean Compound Score: 0.9847
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 94
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|RoomHeaters|ElectricHeaters
#   Mean Compound Score: 0.742055
#   Most Common Sentiment: positive
#   Number of Products: 20
#   Total Reviews: 136
#   Total Ratings: 741
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|RoomHeaters|FanHeaters
#   Mean Compound Score: 0.536725
#   Most Common Sentiment: positive
#   Number of Products: 20
#   Total Reviews: 103
#   Total Ratings: 540
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|RoomHeaters|HalogenHeaters
#   Mean Compound Score: -0.0941
#   Most Common Sentiment: negative
#   Number of Products: 2
#   Total Reviews: 8
#   Total Ratings: 51
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|RoomHeaters|HeatConvectors
#   Mean Compound Score: 0.9916
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 15
#   Total Ratings: 100
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|WaterHeaters&Geysers|ImmersionRods
#   Mean Compound Score: 0.9037999999999999
#   Most Common Sentiment: positive
#   Number of Products: 9
#   Total Reviews: 76
#   Total Ratings: 400
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|WaterHeaters&Geysers|InstantWaterHeaters
#   Mean Compound Score: 0.8072391304347827
#   Most Common Sentiment: positive
#   Number of Products: 23
#   Total Reviews: 152
#   Total Ratings: 795
#
#
# Category: Home&Kitchen|Heating,Cooling&AirQuality|WaterHeaters&Geysers|StorageWaterHeaters
#   Mean Compound Score: 0.8534583333333333
#   Most Common Sentiment: positive
#   Number of Products: 12
#   Total Reviews: 96
#   Total Ratings: 553
#
#
# Category: Home&Kitchen|HomeStorage&Organization|LaundryOrganization|IroningAccessories|SprayBottles
#   Mean Compound Score: 0.9289499999999999
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 99
#
#
# Category: Home&Kitchen|HomeStorage&Organization|LaundryOrganization|LaundryBags
#   Mean Compound Score: 0.9963
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 42
#
#
# Category: Home&Kitchen|HomeStorage&Organization|LaundryOrganization|LaundryBaskets
#   Mean Compound Score: 0.9779
#   Most Common Sentiment: positive
#   Number of Products: 13
#   Total Reviews: 111
#   Total Ratings: 532
#
#
# Category: Home&Kitchen|Kitchen&Dining|KitchenTools|ManualChoppers&Chippers|Choppers
#   Mean Compound Score: 0.9973
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 53
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea&Espresso|CoffeeGrinders|ElectricGrinders
#   Mean Compound Score: 0.9987
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 52
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea&Espresso|CoffeeMakerAccessories|MeasuringSpoons
#   Mean Compound Score: 0.9941333333333334
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 126
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea&Espresso
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers
#   Mean Compound Score: 0.9964
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 41
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SandwichMakers
#   Mean Compound Score: 0.9797454545454546
#   Most Common Sentiment: positive
#   Number of Products: 11
#   Total Reviews: 88
#   Total Ratings: 439
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SmallApplianceParts&Accessories
#   Mean Compound Score: 0.9945
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 45
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SmallApplianceParts&Accessories|StandMixerAccessories
#   Mean Compound Score: 0.9904
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 52
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|StandMixers
#   Mean Compound Score: 0.9678
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 37
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|VacuumSealers
#   Mean Compound Score: 0.5169428571428571
#   Most Common Sentiment: positive
#   Number of Products: 7
#   Total Reviews: 61
#   Total Ratings: 257
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|WaffleMakers&Irons
#   Mean Compound Score: 0.9925
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 78
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|YogurtMakers
#   Mean Compound Score: 0.9862
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 37
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Irons,Steamers&Accessories|Irons|DryIrons
#   Mean Compound Score: 0.9086416666666667
#   Most Common Sentiment: positive
#   Number of Products: 24
#   Total Reviews: 195
#   Total Ratings: 1154
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Irons,Steamers&Accessories|Irons|SteamIrons
#   Mean Compound Score: 0.9911666666666666
#   Most Common Sentiment: positive
#   Number of Products: 12
#   Total Reviews: 103
#   Total Ratings: 509
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Irons,Steamers&Accessories|LintShavers
#   Mean Compound Score: 0.6326227272727273
#   Most Common Sentiment: positive
#   Number of Products: 22
#   Total Reviews: 175
#   Total Ratings: 778
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|PressureWashers,Steam&WindowCleaners
#   Mean Compound Score: 0.9977333333333332
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 97
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|VacuumAccessories|VacuumBags|HandheldBags
#   Mean Compound Score: 0.9524
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 44
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|CanisterVacuums
#   Mean Compound Score: 0.997225
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 25
#   Total Ratings: 140
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|HandheldVacuums
#   Mean Compound Score: 0.7564625
#   Most Common Sentiment: positive
#   Number of Products: 8
#   Total Reviews: 62
#   Total Ratings: 310
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|RoboticVacuums
#   Mean Compound Score: 0.9973
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 14
#   Total Ratings: 91
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|Wet-DryVacuums
#   Mean Compound Score: 0.9987833333333334
#   Most Common Sentiment: positive
#   Number of Products: 6
#   Total Reviews: 50
#   Total Ratings: 220
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|WaterPurifiers&Accessories|WaterCartridges
#   Mean Compound Score: 0.7913333333333333
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 24
#   Total Ratings: 129
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|WaterPurifiers&Accessories|WaterFilters&Purifiers
#   Mean Compound Score: 0.6194583333333333
#   Most Common Sentiment: positive
#   Number of Products: 12
#   Total Reviews: 84
#   Total Ratings: 468
#
#
# Category: Home&Kitchen|Kitchen&HomeAppliances|WaterPurifiers&Accessories|WaterPurifierAccessories
#   Mean Compound Score: 0.6475545454545455
#   Most Common Sentiment: positive
#   Number of Products: 11
#   Total Reviews: 80
#   Total Ratings: 380
#
#
# Category: HomeImprovement|Electrical|Adapters&Multi-Outlets
#   Mean Compound Score: 0.0
#   Most Common Sentiment: neutral
#   Number of Products: 1
#   Total Reviews: 0
#   Total Ratings: 0
#
#
# Category: HomeImprovement|Electrical|CordManagement
#   Mean Compound Score: 0.9984
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 34
#
#
# Category: MusicalInstruments|Microphones|Condenser
#   Mean Compound Score: 0.9746999999999999
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 15
#   Total Ratings: 82
#
#
# Category: OfficeProducts|OfficeElectronics|Calculators|Basic
#   Mean Compound Score: 0.9982
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 32
#
#
# Category: OfficeProducts|OfficeElectronics|Calculators|Financial&Business
#   Mean Compound Score: 0.9722
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 43
#
#
# Category: OfficeProducts|OfficeElectronics|Calculators|Scientific
#   Mean Compound Score: 0.9942
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 26
#   Total Ratings: 81
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Copy&PrintingPaper|ColouredPaper
#   Mean Compound Score: 0.9818
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 38
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Notebooks,WritingPads&Diaries
#   Mean Compound Score: 0.9976
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 8
#   Total Ratings: 32
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Notebooks,WritingPads&Diaries|CompositionNotebooks
#   Mean Compound Score: 0.9644285714285715
#   Most Common Sentiment: positive
#   Number of Products: 7
#   Total Reviews: 58
#   Total Ratings: 269
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Notebooks,WritingPads&Diaries|Notepads&MemoBooks
#   Mean Compound Score: 0.99865
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 16
#   Total Ratings: 73
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Notebooks,WritingPads&Diaries|WireboundNotebooks
#   Mean Compound Score: 0.984925
#   Most Common Sentiment: positive
#   Number of Products: 4
#   Total Reviews: 32
#   Total Ratings: 163
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|BottledInk
#   Mean Compound Score: 0.99585
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 21
#   Total Ratings: 85
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|FountainPens
#   Mean Compound Score: 0.9998
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 12
#   Total Ratings: 42
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens
#   Mean Compound Score: 0.99455
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 18
#   Total Ratings: 80
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|LiquidInkRollerballPens
#   Mean Compound Score: 0.98805
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 17
#   Total Ratings: 67
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|RetractableBallpointPens
#   Mean Compound Score: 0.99535
#   Most Common Sentiment: positive
#   Number of Products: 2
#   Total Reviews: 21
#   Total Ratings: 74
#
#
# Category: OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|StickBallpointPens
#   Mean Compound Score: 0.9475666666666666
#   Most Common Sentiment: positive
#   Number of Products: 3
#   Total Reviews: 29
#   Total Ratings: 111
#
#
# Category: Toys&Games|Arts&Crafts|Drawing&PaintingSupplies|ColouringPens&Markers
#   Mean Compound Score: 0.9959
#   Most Common Sentiment: positive
#   Number of Products: 1
#   Total Reviews: 13
#   Total Ratings: 37

# %% [markdown]
# ### 5. Topic Modelling

# %%
# Load the reviews from the CSV file
df = pd.read_csv('all_amazon_reviews_with_summary_safari.csv')

# Handle missing values by filling NaNs in the 'reviews' column with empty strings
df['reviews'] = df['reviews'].fillna('')

# Preprocessing: we focus on terms likely to relate to supplier performance
tfidf_vectorizer = TfidfVectorizer(
    stop_words='english',
    max_df=0.95,  # Ignore terms that appear in more than 95% of documents
    min_df=2,     # Ignore terms that appear in less than 2 documents
    ngram_range=(1, 2)  # Include bigrams (two-word combinations) for phrases like "delivery time"
)

# Transform the reviews into the TF-IDF matrix
X = tfidf_vectorizer.fit_transform(df['reviews'])

# Set up LDA to extract a few specific topics (for instance, 5 topics)
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_model.fit(X)

# Function to display the topics with top words
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# Display the top words in each topic
feature_names = tfidf_vectorizer.get_feature_names_out()
display_topics(lda_model, feature_names, 10)

# Assign topics to each review
def assign_topics_to_reviews(lda_model, tfidf_matrix):
    topic_assignments = lda_model.transform(tfidf_matrix)
    return topic_assignments.argmax(axis=1)

df['topic'] = assign_topics_to_reviews(lda_model, X)

# Save the data with topics assigned to each review
output_file = 'reviews_with_supplier_topics.csv'
df.to_csv(output_file, index=False)

print(f"Topic modeling completed and saved to: {output_file}")
# Out:
# Topic 0:
# m33 | chal rhi | rhi | chal | charging output | boat micro | usb 55 | galaxy m33 | m33 5g | 4a fast
# Topic 1:
# good | product | cable | quality | charging | use | tv | price | working | phone
# Topic 2:
# cable protectors | watch faces | faces | soooo | ui | 10a | redmi 10a | longer cable | protectors | m13
# Topic 3:
# boat 350 | printer laptop | visionary | ehs64 | sd cards | 350 type | memory card | 4k video | boltt visionary | ninja
# Topic 4:
# smartwatch | ninja pro | boltt ninja | ninja | tracking features | phoenix | m04 | galaxy m04 | health tracking | unbreakable
# Topic modeling completed and saved to: reviews_with_supplier_topics.csv

# %% [markdown]
# Topic 0:
# - Top Words: m33 | chal rhi | rhi | charging output | boat micro | usb 55 | galaxy m33 | m33 5g | 4a fast
# - Interpretation: This topic seems to focus on technical product details, specifically related to mobile devices (e.g., Galaxy M33) and charging outputs. The mention of "USB" and "fast charging" could indicate discussions about compatibility, speed, and output issues. This topic might reflect customer feedback on charging speeds and whether the products meet expectations.
#
# Topic 1:
# - Top Words: good | product | cable | quality | charging | use | tv | price | working | phone
# - Interpretation: This is a more general topic about product quality, where users talk about the quality of cables, the price, and whether the product is working as intended. There may be discussions about the functionality of products related to charging or general use with phones or TVs. This topic reflects overall satisfaction with product quality and value for money.
#
# Topic 2:
# - Top Words: cable protectors | watch faces | faces | soooo | ui | 10a | redmi 10a | longer cable | protectors | m13
# - Interpretation: This topic seems to focus on accessories, such as cable protectors and watch faces, as well as references to specific mobile devices like Redmi 10a and M13. The mention of "longer cable" might indicate feedback on cable lengths. This topic could involve feedback about the durability or design of accessories and additional protective items.
#
# Topic 3:
# - Top Words: boat 350 | printer laptop | visionary | ehs64 | sd cards | 350 type | memory card | 4k video | boltt visionary | ninja
# - Interpretation: This topic includes a variety of tech gadgets, such as printers, SD cards, and memory cards, as well as mentions of 4K video. It's likely related to storage, memory, and possibly connectivity with laptops or devices. Customers might be discussing performance of these products, especially when handling high-quality video or storage needs.
#
# Topic 4:
# - Top Words: smartwatch | ninja pro | boltt ninja | ninja | tracking features | phoenix | m04 | galaxy m04 | health tracking | unbreakable
# - Interpretation: This topic focuses on smartwatches and fitness-related features like health tracking. Words like unbreakable and mentions of specific smartwatch models (e.g., Boltt Ninja, Galaxy M04) suggest discussions around durability and functionality of wearables, particularly in terms of tracking fitness activities.
#
# Summary of Insights:
# - Supplier Performance: Several topics seem to address customer feedback on product quality and functionality (e.g., charging speeds, cable durability, health tracking features). There may be insights related to compatibility with specific devices (e.g., Galaxy M33, Redmi 10a).
# - Potential Bottlenecks: Topic 0 and Topic 1 could provide insights into possible performance issues, such as charging speeds or product working as expected, which may be related to supplier performance.
# - Durability and Design: Topics 1, 2, and 4 mention features like cable protectors, longer cables, and unbreakable features, indicating that durability and product design are key concerns for customers.
# - Tech Gadgets: Topic 3 suggests feedback about more niche products like memory cards, SD cards, and printers, which may help identify any performance issues or variability in delivery times for these items.

# %% [markdown]
# ### 6. Topic Modelling on Neutral/Negative Reviews

# %%
# Load the CSV with sentiment analysis results
file_path = 'sentiment_analysis_results.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)

# Filter out neutral and negative sentiment reviews
filtered_reviews = df[(df['sentiment'] == 'neutral') | (df['sentiment'] == 'negative')]

# Drop rows with NaN values in the 'reviews' column
filtered_reviews = filtered_reviews.dropna(subset=['reviews'])

# Check how many reviews we have after filtering and dropping NaN values
print(f"Filtered reviews count: {len(filtered_reviews)}")

# Preprocessing: we'll use TF-IDF for topic modeling
tfidf_vectorizer = TfidfVectorizer(
    stop_words='english',
    max_df=0.95,  # Ignore terms that appear in more than 95% of documents
    min_df=2,     # Ignore terms that appear in less than 2 documents
    ngram_range=(1, 2)  # Consider bigrams to capture phrases like "delivery time"
)

# Transform the filtered reviews into the TF-IDF matrix
X = tfidf_vectorizer.fit_transform(filtered_reviews['reviews'])

# Apply LDA to extract 5 topics (adjust number of topics as needed)
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_model.fit(X)

# Display the topics with top words
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" | ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# Extract the feature names from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Display the top 10 words for each topic
display_topics(lda_model, feature_names, 10)

# Assign topics to each review and add it to the DataFrame
def assign_topics_to_reviews(lda_model, tfidf_matrix):
    topic_assignments = lda_model.transform(tfidf_matrix)
    return topic_assignments.argmax(axis=1)

filtered_reviews['topic'] = assign_topics_to_reviews(lda_model, X)

# Save the filtered reviews with topics to a new CSV file
output_file = 'filtered_reviews_with_topics.csv'
filtered_reviews.to_csv(output_file, index=False)

print(f"Topic modeling completed and saved to: {output_file}")
# Out:
# Filtered reviews count: 39
# Topic 0:
# product | cable | waste | quality | hair | buy | working | wire | health | original
# Topic 1:
# remote | tv | good | product | bajaj | dust | room | paper | cleaning | job
# Topic 2:
# water | product | quality | filter | hp | working | use | service | plastic | cartridge
# Topic 3:
# cable | room | charging | button | sound | volume | hot | blade | product | type
# Topic 4:
# product | good | batteries | charger | warrenty | working | quality | charging | saw | amazon
# Topic modeling completed and saved to: filtered_reviews_with_topics.csv

# %% [markdown]
# ### 7. Analyze Supplier Performance and Identify Bottlenecks
#
# Topic 0:
# - Keywords like product, cable, waste, quality, working, wire, and health suggest issues with cable products, potentially related to poor quality or product waste. There might be concerns about health or environmental impact related to the materials used in these products.
# - Bottleneck: Quality control issues with cable products, possibly leading to higher return rates or dissatisfaction.
#
# Topic 1:
# - The keywords include remote, tv, good, product, dust, and cleaning. This could indicate that certain remote control or TV products require frequent cleaning or have issues with dust buildup.
# - Bottleneck: The design of these products may not be conducive to long-term cleanliness, affecting performance and user satisfaction.
#
# Topic 2:
# - Words like water, filter, working, service, plastic, and cartridge indicate issues with water filter products, possibly related to product durability or replacement issues (e.g., cartridges).
# - Bottleneck: The frequent need for cartridge replacement or service could be a supply chain challenge, leading to delays or higher costs for maintaining these products.
#
# Topic 3:
# - Keywords like charging, button, sound, volume, and blade suggest issues related to electronics or devices with buttons, sound control, and charging functionality.
# - Bottleneck: Charging problems and malfunctioning buttons could point to product defects or short lifespan, affecting customer experience and returns.
#
# Topic 4:
# - This topic revolves around batteries, charger, warranty, and amazon. It seems to cover battery and charger-related products, possibly highlighting warranty issues or the need for frequent replacements.
# - Bottleneck: Frequent battery or charger replacements due to malfunction or insufficient warranty coverage could be a bottleneck in terms of both product quality and customer service.

# %% [markdown]
# ### 8. Possible Optimisation (Based on bottleneck identified in topic modelling)

# %% [markdown]
# Quality Control for Cable Products (Topic 0)
# - Optimization: Implement stricter quality checks during the manufacturing process, focusing on durability tests for cables and wires. Collaborating with suppliers to improve material quality could reduce waste and improve health and safety standards.
# - Automation: Use automated testing systems to check for cable integrity before shipping to reduce faulty products reaching customers.
#
# Design Optimization for Remote/TV Products (Topic 1)
# - Optimization: Redesign products to minimize dust buildup or improve ease of cleaning. Alternatively, offer accessories or cleaning kits bundled with the products.
# - Automation: Automate customer service notifications for cleaning and maintenance advice, or offer subscription services for regular product upkeep.
#
# Inventory and Replacement Strategy for Water Filter Products (Topic 2)
# - Optimization: Optimize inventory management to ensure that replacement cartridges are always available when customers need them. Consider offering subscription services for regular cartridge replacement to reduce delivery times and improve customer satisfaction.
# - Automation: Automate order tracking and notifications for cartridge replacements, ensuring that users are reminded before they need new cartridges.
#
# Improved Product Durability for Electronic Devices (Topic 3)
# - Optimization: Collaborate with manufacturers to improve button durability and charging reliability through better design and testing. Offering extended warranties could also alleviate customer concerns.
# - Automation: Automate fault detection using smart sensors in electronic devices, which could notify the supplier of potential failures before they occur, improving service times and reducing product returns.
#
# Battery and Charger Warranty Extension (Topic 4)
# - Optimization: Negotiate with suppliers to offer better warranties on batteries and chargers, which could reduce the number of dissatisfied customers. Offering extended warranty packages or providing free replacements within a certain period could enhance customer loyalty.
# - Automation: Use predictive analytics to anticipate battery or charger failures based on usage patterns and offer proactive replacements, reducing customer downtime.

# %% [markdown]
# ### 9. Possible Improvement to Order Fulfilment
#
# To improve order fulfillment and reduce delivery times, the following strategies can be employed:
#
# Demand Forecasting:
# - Utilize demand forecasting models to anticipate peak periods for replacement products like cartridges, batteries, and chargers, ensuring sufficient stock is available to avoid delays.
#
# Supplier Performance Analysis:
# - Use the sentiment data from your reviews (especially from Topic 0, 2, and 4) to evaluate suppliers' performance based on customer feedback. Terminate contracts with underperforming suppliers or negotiate performance improvements.
#
# Inventory Optimization:
# - Implement a Just-In-Time (JIT) inventory system for fast-moving replacement products (cartridges, batteries), ensuring that you don't run out of stock while minimizing holding costs.
#
# Automating Order Fulfillment:
# - Integrate automated systems to manage inventory levels, track orders, and optimize delivery routes. Tools like barcode scanning and real-time inventory updates can help ensure accuracy in order fulfillment.
#
# Delivery Time Reduction:
# - Consider using localized fulfillment centers for popular products to reduce shipping times. Partner with logistics providers to optimize last-mile delivery, ensuring products reach customers faster.

# %% [markdown]
# ### 10. Dashboard

# %%
# Example data from your project
data = {
    'Category': [
        'Stovetop Espresso Pots', 'Sewing & Embroidery Machines', 'Small Kitchen Appliances', 
        'Air Fryers', 'Digital Kitchen Scales', 'Egg Boilers', 'Hand Blenders'
    ],
    'Mean Compound Score': [0.9965, 0.9955, 0.9997, 0.712, 0.8540, 0.9884, 0.8579],
    'Total Reviews': [13, 32, 8, 45, 77, 90, 148],
    'Total Ratings': [36, 153, 44, 237, 361, 474, 701],
    'Number of Products': [1, 4, 1, 5, 10, 11, 19],
    'Most Common Sentiment': ['positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive']
}

# Convert the data to a pandas DataFrame
df = pd.DataFrame(data)

# Create a column for average ratings per product
df['Average Ratings'] = df['Total Ratings'] / df['Number of Products']

# Initialize Dash app
app = Dash(__name__)

# Layout of the dashboard
app.layout = html.Div([
    html.H1("Amazon Reviews Sentiment Analysis Dashboard"),

    # Dropdown filter for category selection
    dcc.Dropdown(
        id='category-filter',
        options=[{'label': cat, 'value': cat} for cat in df['Category']],
        value=df['Category'].tolist(),  # Default to all categories
        multi=True,
        placeholder="Select categories"
    ),

    # Bar chart for mean compound scores
    dcc.Graph(id='sentiment-bar'),

    # Pie chart for total reviews
    dcc.Graph(id='reviews-pie'),

    # Bar chart for total ratings
    dcc.Graph(id='ratings-bar'),

    # Bar chart for average ratings per product
    dcc.Graph(id='avg-ratings-bar'),

    # Summary Table for key metrics
    html.Div(id='summary-table')
])

# Update all graphs when category filter changes
@app.callback(
    [Output('sentiment-bar', 'figure'),
     Output('reviews-pie', 'figure'),
     Output('ratings-bar', 'figure'),
     Output('avg-ratings-bar', 'figure'),
     Output('summary-table', 'children')],
    [Input('category-filter', 'value')]
)
def update_dashboard(selected_categories):
    # Filter data based on selected categories
    filtered_df = df[df['Category'].isin(selected_categories)]

    # Bar chart for mean compound scores
    sentiment_bar = px.bar(
        filtered_df, 
        x='Category', 
        y='Mean Compound Score', 
        color='Most Common Sentiment',
        title="Mean Compound Sentiment Score by Category"
    )

    # Pie chart for total reviews
    reviews_pie = px.pie(
        filtered_df, 
        names='Category', 
        values='Total Reviews', 
        title="Distribution of Total Reviews by Category"
    )

    # Bar chart for total ratings
    ratings_bar = px.bar(
        filtered_df, 
        x='Category', 
        y='Total Ratings', 
        title="Total Ratings by Category"
    )

    # Bar chart for average ratings per product
    avg_ratings_bar = px.bar(
        filtered_df, 
        x='Category', 
        y='Average Ratings',
        title="Average Ratings per Product by Category (out of 50)
        "
    )

    # Summary table for key metrics
    summary_table = html.Table([
        html.Tr([html.Th("Metric"), html.Th("Value")]),
        html.Tr([html.Td("Total Categories"), html.Td(len(filtered_df))]),
        html.Tr([html.Td("Total Products"), html.Td(filtered_df['Number of Products'].sum())]),
        html.Tr([html.Td("Total Reviews"), html.Td(filtered_df['Total Reviews'].sum())]),
        html.Tr([html.Td("Total Ratings"), html.Td(filtered_df['Total Ratings'].sum())]),
        html.Tr([html.Td("Average Sentiment Score"), html.Td(round(filtered_df['Mean Compound Score'].mean(), 4))])
    ])

    return sentiment_bar, reviews_pie, ratings_bar, avg_ratings_bar, summary_table

# Run the Dash app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
